# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %% [markdown]
# #### Read Dataset

# %%
df = pd.read_csv('train_ctrUa4K.csv')
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.describe(include='O')
# Out:
#          Loan_ID Gender Married Dependents Education Self_Employed  \
# count        614    601     611        599       614           582
# unique       614      2       2          4         2             2
# top     LP001002   Male     Yes          0  Graduate            No
# freq           1    489     398        345       480           500
#
#        Property_Area Loan_Status
# count            614         614
# unique             3           2
# top        Semiurban           Y
# freq             233         422

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop(['Loan_ID'] , axis = 1 , inplace = True )

# %%
for col in df.select_dtypes('number').columns :
    
    plt.figure()
    sns.histplot(data = df , x = col)

# %%
df[df['Loan_Amount_Term'] > 360]
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 75     Male      No          0      Graduate            No             3750
# 109    Male     Yes         3+  Not Graduate            No             2071
# 130    Male      No          0      Graduate           Yes            20166
# 168    Male      No          0      Graduate            No             2237
# 179    Male      No          0  Not Graduate            No             2333
# 228    Male     NaN        NaN      Graduate            No             4758
# 248    Male     Yes          1      Graduate            No             2882
# 293  Female      No        NaN      Graduate            No             5417
# 298  Female      No          0      Graduate            No             5000
# 358    Male     Yes          0  Not Graduate            No             3000
# 366    Male      No          0      Graduate            No             2500
# ...

# %%
for col in df.select_dtypes('object').columns :
    
    
    plt.figure()
    sns.countplot(data = df , x = col)

# %%
for col in df.select_dtypes('number').columns :
    
    plt.figure()
    sns.histplot(data = df , x = col , hue = 'Loan_Status')

# %%
for col in df.select_dtypes('number').columns :
    
    plt.figure()
    sns.histplot(data = df , x = np.log1p(df[col]) , hue = 'Loan_Status')

# %%
for col in df.select_dtypes('object').columns :
    
    
    plt.figure()
    sns.countplot(data = df , x = col , hue = 'Loan_Status')

# %%
sns.pairplot(df , hue = 'Loan_Status')

# %%
sns.heatmap(df.select_dtypes('number').corr() , annot=True )
# Out:
# <Axes: >

# %% [markdown]
# #### Data Preparation & Modeling

# %%
df['Dependents'].unique()
# Out:
# array(['0', '1', '2', '3+', nan], dtype=object)

# %%
df['Dependents'] = df['Dependents'].apply(lambda x : int(x[0]) if type(x) == str else x)

# %%
df['Loan_Status'].unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %%
df['Loan_Status'] = df['Loan_Status'].apply(lambda x : 1 if x == 'Y' else 0)

# %%
df.select_dtypes('object').isnull().sum()
# Out:
# Gender           13
# Married           3
# Education         0
# Self_Employed    32
# Property_Area     0
# dtype: int64

# %%
for col in df.select_dtypes('object').columns:
    print(f"{col}-----{df[col].nunique()} ")
# Out:
# Gender-----2
# Married-----2
# Education-----2
# Self_Employed-----2
# Property_Area-----3

# %%
df.select_dtypes('number').isnull().sum()
# Out:
# Dependents           15
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Loan_Status           0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler , PolynomialFeatures , OneHotEncoder
from category_encoders import BinaryEncoder
from sklearn.impute import KNNImputer , SimpleImputer

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

from sklearn.metrics import accuracy_score , f1_score , recall_score , precision_score , confusion_matrix , ConfusionMatrixDisplay
from sklearn.model_selection import cross_validate , GridSearchCV ,StratifiedKFold, train_test_split
from sklearn.feature_selection import SelectFromModel

from imblearn.pipeline import make_pipeline
from sklearn.preprocessing import FunctionTransformer
from sklearn.compose import ColumnTransformer

from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.decomposition import PCA


from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler

# %%
x , y  = df.drop(['Loan_Status'] , axis=1) , df['Loan_Status']

# %% [markdown]
# * category columns
# >* impute missing + ohe encoder
# >* impute missing + be encoder

# %%
df.select_dtypes('object').isnull().sum()
# Out:
# Gender           13
# Married           3
# Education         0
# Self_Employed    32
# Property_Area     0
# dtype: int64

# %%
ohe_pl = make_pipeline(SimpleImputer(strategy='most_frequent') , 
                       OneHotEncoder(sparse_output=False , drop='first'))


be_pl = make_pipeline(SimpleImputer(strategy='most_frequent') , BinaryEncoder())


categorical_preprocessing = ColumnTransformer(transformers=[
    ('ohe_pl',ohe_pl , ['Gender','Married','Education','Self_Employed']),
    ('be_pl' ,be_pl , ['Property_Area'])
],remainder='passthrough')
categorical_preprocessing
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('ohe_pl',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False))]),
#                                  ['Gender', 'Married', 'Education',
#                                   'Self_Employed']),
#                                 ('be_pl',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('binaryencoder',
#                                                   BinaryEncoder())]),
# ...

# %%
categorical_preprocessing.fit_transform(x)
# Out:
# array([[  1.,   0.,   0., ...,  nan, 360.,   1.],
#        [  1.,   1.,   0., ..., 128., 360.,   1.],
#        [  1.,   1.,   0., ...,  66., 360.,   1.],
#        ...,
#        [  1.,   1.,   0., ..., 253., 360.,   1.],
#        [  1.,   1.,   0., ..., 187., 360.,   1.],
#        [  0.,   0.,   0., ..., 133., 360.,   0.]])

# %% [markdown]
# * numeric columns
# >* imputing missing + log
# >* imputing missing

# %%
df.select_dtypes('number').isnull().sum()
# Out:
# Dependents           15
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Loan_Status           0
# dtype: int64

# %%
log_missing_pl = make_pipeline(KNNImputer() , 
                               FunctionTransformer(np.log1p))

most_freq_pl = make_pipeline(SimpleImputer(strategy='most_frequent'))

numeric_preprocessing = ColumnTransformer(transformers=[
    ('log_missing_pl' , log_missing_pl , ['ApplicantIncome','CoapplicantIncome','LoanAmount']),
    ('most_freq_pl' , most_freq_pl , ['Dependents','Loan_Amount_Term','Credit_History'])
],remainder='passthrough')
numeric_preprocessing
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('log_missing_pl',
#                                  Pipeline(steps=[('knnimputer', KNNImputer()),
#                                                  ('functiontransformer',
#                                                   FunctionTransformer(func=<ufunc 'log1p'>))]),
#                                  ['ApplicantIncome', 'CoapplicantIncome',
#                                   'LoanAmount']),
#                                 ('most_freq_pl',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent'))]),
#                                  ['Dependents', 'Loan_Amount_Term',
#                                   'Credit_History'])])

# %%
preprocessing = ColumnTransformer(transformers=[
    ('categorical_preprocessing',categorical_preprocessing , ['Gender','Married','Education','Self_Employed','Property_Area']),
    ('numeric_preprocessing',numeric_preprocessing , ['ApplicantIncome','CoapplicantIncome','LoanAmount',
                                                      'Dependents','Loan_Amount_Term','Credit_History'])
],remainder='passthrough')
preprocessing
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('categorical_preprocessing',
#                                  ColumnTransformer(remainder='passthrough',
#                                                    transformers=[('ohe_pl',
#                                                                   Pipeline(steps=[('simpleimputer',
#                                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                                   ('onehotencoder',
#                                                                                    OneHotEncoder(drop='first',
#                                                                                                  sparse_output=False))]),
#                                                                   ['Gender',
#                                                                    'Married',
# ...

# %%
model = make_pipeline(preprocessing , StandardScaler(), SelectFromModel(estimator=RandomForestClassifier()),
                      PolynomialFeatures(degree=2) , LogisticRegression(max_iter=1000))
model
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('categorical_preprocessing',
#                                                   ColumnTransformer(remainder='passthrough',
#                                                                     transformers=[('ohe_pl',
#                                                                                    Pipeline(steps=[('simpleimputer',
#                                                                                                     SimpleImputer(strategy='most_frequent')),
#                                                                                                    ('onehotencoder',
#                                                                                                     OneHotEncoder(drop='first',
# ...

# %%
cv = cross_validate(estimator=model , X=x , y=y , cv = 5 , scoring='accuracy' , return_train_score=True)

# %%
cv['train_score'].mean()
# Out:
# 0.8131116188962298

# %%
cv['test_score'].mean()
# Out:
# 0.8061975209916034

# %%
model1 = make_pipeline(preprocessing , StandardScaler() , SequentialFeatureSelector(estimator=DecisionTreeClassifier(),
                                                                                n_features_to_select=3,cv=5,scoring='accuracy',
                                                                                  direction='forward') ,
                    SVC())
model1
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('categorical_preprocessing',
#                                                   ColumnTransformer(remainder='passthrough',
#                                                                     transformers=[('ohe_pl',
#                                                                                    Pipeline(steps=[('simpleimputer',
#                                                                                                     SimpleImputer(strategy='most_frequent')),
#                                                                                                    ('onehotencoder',
#                                                                                                     OneHotEncoder(drop='first',
# ...

# %%
cv = cross_validate(estimator=model1 , X=x , y=y , cv = 5 , scoring='accuracy' , return_train_score=True)

# %%
cv['train_score'].mean()
# Out:
# 0.8106692828639079

# %%
cv['test_score'].mean()
# Out:
# 0.8045848327335733

# %%
model.steps
# Out:
# [('columntransformer',
#   ColumnTransformer(remainder='passthrough',
#                     transformers=[('categorical_preprocessing',
#                                    ColumnTransformer(remainder='passthrough',
#                                                      transformers=[('ohe_pl',
#                                                                     Pipeline(steps=[('simpleimputer',
#                                                                                      SimpleImputer(strategy='most_frequent')),
#                                                                                     ('onehotencoder',
#                                                                                      OneHotEncoder(drop='first',
#                                                                                                    sparse_output=False))]),
#                                                                     ['Gender',
# ...

# %%
lr_pram = [
    {
        'polynomialfeatures__degree' : [1 ,2 , 3 ],
        'logisticregression__C' : [0.1 , 0.5 , 1 , 5 , 10]
    }
]

# %%
lr_srch = GridSearchCV(estimator=model ,param_grid=lr_pram , cv = 5 , scoring='accuracy' , return_train_score=True)

# %%
lr_srch.fit(x , y)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('columntransformer',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('categorical_preprocessing',
#                                                                          ColumnTransformer(remainder='passthrough',
#                                                                                            transformers=[('ohe_pl',
#                                                                                                           Pipeline(steps=[('simpleimputer',
#                                                                                                                            SimpleImputer(strategy='most_frequent')),
#                                                                                                                           ('onehotencoder',
# ...

# %%
lr_srch.best_estimator_
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('categorical_preprocessing',
#                                                   ColumnTransformer(remainder='passthrough',
#                                                                     transformers=[('ohe_pl',
#                                                                                    Pipeline(steps=[('simpleimputer',
#                                                                                                     SimpleImputer(strategy='most_frequent')),
#                                                                                                    ('onehotencoder',
#                                                                                                     OneHotEncoder(drop='first',
# ...

# %%
lr_srch.best_params_
# Out:
# {'logisticregression__C': 0.1, 'polynomialfeatures__degree': 1}

# %%
lr_srch.best_score_
# Out:
# 0.809462881514061

# %%
import joblib
joblib.dump(lr_srch.best_estimator_,'LR.h5')
# Out:
# ['LR.h5']
